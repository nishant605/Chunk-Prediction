# %%
import numpy as np
import pandas as pd

# %%
import pickle

# %%
pipe = pickle.load(open("churn_pipeline.pkl", "rb"))

# %%
pipe
# Out:
# Pipeline(steps=[('model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
# ...

# %%
import pandas as pd

new_customer = pd.DataFrame([{
    "Tenure": 12,
    "Usage Frequency": 5,
    "Support Calls": 2,
    "Payment Delay": 3,
    "Last Interaction": 10,
    "Total Spend": 500,
    "Subscription Type_Standard": 0,
    "Subscription Type_Premium": 1,
    "Subscription Type_Basic": 0
}])

# %%
new_customer = pd.DataFrame([{
    "Tenure": 2,
    "Usage Frequency": 1,
    "Support Calls": 25,
    "Payment Delay": 20,
    "Last Interaction": 1,
    "Total Spend": 100,
    "Subscription Type_Standard": 0,
    "Subscription Type_Premium": 0,
    "Subscription Type_Basic": 1
}])

# %%
new_customer
# Out:
#    Tenure  Usage Frequency  Support Calls  Payment Delay  Last Interaction  \
# 0      32               35              2              0                 1
#
#    Total Spend  Subscription Type_Standard  Subscription Type_Premium  \
# 0         5500                           0                          1
#
#    Subscription Type_Basic
# 0                        0

# %%
pred = pipe.predict(new_customer)
prob = pipe.predict_proba(new_customer)[0][1]

print("Prediction:", pred)

if pred[0] == 1:
    print("Customer will CHURN ❌")
else:
    print("Customer will NOT churn ✅")

print("Churn Probability:", prob)
# Out:
# Prediction: [1]
# Customer will CHURN ❌
# Churn Probability: 0.9999933
